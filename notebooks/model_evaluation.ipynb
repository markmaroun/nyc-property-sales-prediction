# %% [markdown]
# ###Download Libraries

# %%
pip install google.colab numpy matplotlib scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ###Import Libraries

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# %run '/content/drive/My Drive/Colab Notebooks/model_development.ipynb'
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.8 MB/s eta 0:00:00
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Mean Absolute Error: 0.29354711134676675

# %% [markdown]
# ###Model Validation

# %%
y_pred_valid = model.predict(X_valid)

mse = mean_squared_error(Y_valid, y_pred_valid)
mae = mean_absolute_error(Y_valid, y_pred_valid)
rmse = numpy.sqrt(mse)
r2 = r2_score(Y_valid, y_pred_valid)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R^2 Score:", r2)

plt.figure(figsize=(10, 6))
plt.scatter(Y_valid, y_pred_valid, alpha=0.3)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices')
plt.plot([min(Y_valid), max(Y_valid)], [min(Y_valid), max(Y_valid)], 'k--', lw=4)  # Line for perfect predictions
plt.show()


residuals = Y_valid - y_pred_valid
plt.figure(figsize=(10, 6))
plt.scatter(y_pred_valid, residuals, alpha=0.3)
plt.title('Residual Plot')
plt.xlabel('Predicted Prices')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='-')
plt.show()
# Out:
# Mean Absolute Error: 0.302114089011479
# Mean Squared Error: 0.29003953803137295
# Root Mean Squared Error: 0.5385531896028218
# R^2 Score: 0.7165799447336683
